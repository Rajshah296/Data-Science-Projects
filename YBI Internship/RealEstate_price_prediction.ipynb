# %% [markdown]
# In this project, we are going to create different Regression-based models for predicting the house prices in Boston based on various factors. We will create various models and select the model with the best accuracy at the end. Before that we will also import the dataset and apply some transformations on it to refine it for our Regression models.

# %% [markdown]
# # Import all the required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
import scipy.stats as stats

# %% [markdown]
# # Boston Housing Dataset

# %%
df = pd.read_csv('Datasets/Boston.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NX       506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS          NX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NX         0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
target_corr = np.abs(df.corrwith(df['MEDV']))
print(target_corr.sort_values(ascending=False))
# Out:
# MEDV       1.000000
# LSTAT      0.737663
# RM         0.695360
# PTRATIO    0.507787
# INDUS      0.483725
# TAX        0.468536
# NX         0.427321
# CRIM       0.388305
# RAD        0.381626
# AGE        0.376955
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# dtype: float64

# %%
df = df.drop(['CHAS', 'DIS','B'], axis=1)
df
# Out:
#         CRIM    ZN  INDUS     NX     RM   AGE  RAD    TAX  PTRATIO  LSTAT  \
# 0    0.00632  18.0   2.31  0.538  6.575  65.2    1  296.0     15.3   4.98
# 1    0.02731   0.0   7.07  0.469  6.421  78.9    2  242.0     17.8   9.14
# 2    0.02729   0.0   7.07  0.469  7.185  61.1    2  242.0     17.8   4.03
# 3    0.03237   0.0   2.18  0.458  6.998  45.8    3  222.0     18.7   2.94
# 4    0.06905   0.0   2.18  0.458  7.147  54.2    3  222.0     18.7   5.33
# ..       ...   ...    ...    ...    ...   ...  ...    ...      ...    ...
# 501  0.06263   0.0  11.93  0.573  6.593  69.1    1  273.0     21.0   9.67
# 502  0.04527   0.0  11.93  0.573  6.120  76.7    1  273.0     21.0   9.08
# 503  0.06076   0.0  11.93  0.573  6.976  91.0    1  273.0     21.0   5.64
# 504  0.10959   0.0  11.93  0.573  6.794  89.3    1  273.0     21.0   6.48
# 505  0.04741   0.0  11.93  0.573  6.030  80.8    1  273.0     21.0   7.88
#
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 11 columns]

# %%
X = df.drop(['MEDV'], axis=1)
y = df['MEDV']
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=2529,test_size=0.2)

print(X_train.shape)
print(X_test.shape)
# Out:
# (404, 10)
# (102, 10)

# %% [markdown]
# # Linear Regression with only Standardization and no PowerTransformers

# %%
# Applying Regression without any transformation
lr = LinearRegression()
std = StandardScaler()
X_train_transformed = std.fit_transform(X_train)
X_test_transformed = std.transform(X_test)
lr.fit(X_train_transformed,y_train)

y_pred = lr.predict(X_test_transformed)


r2_score(y_test,y_pred)
# Out:
# 0.6442041772047282

# %%
np.mean(cross_val_score(lr,X,y,scoring='r2', cv=10))
# Out:
# 0.105806033547411

# %%
# for col in X_train.columns:
#     plt.figure(figsize=(14,4))
#     plt.subplot(121)
#     sns.kdeplot(X_train[col])
#     plt.title(col)

#     plt.subplot(122)
#     stats.probplot(X_train[col], dist="norm", plot=plt)
#     plt.title(col)

#     plt.show()

# %%
pt = PowerTransformer(method='box-cox')
pt2 = PowerTransformer()
X_train_transformed_box = pt.fit_transform(X_train+0.000001)
X_test_transformed_box = pt.transform(X_test+0.000001)
X_train_transformed_yeo = pt2.fit_transform(X_train)
X_test_transformed_yeo = pt2.transform(X_test)

# %%
# Before/After Transformation comparison using Box-Cox and Yeo-Johnson.

# X_train_transformed_box = pd.DataFrame(X_train_transformed_box,columns=X_train.columns)
# X_train_transformed_yeo = pd.DataFrame(X_train_transformed_yeo,columns=X_train.columns)
# for col in X_train_transformed_box.columns:
#     plt.figure(figsize=(14,4))
#     plt.subplot(131)
#     sns.kdeplot(X_train[col])
#     plt.title(col)

#     plt.subplot(132)
#     sns.kdeplot(X_train_transformed_box[col])
#     plt.title('Box-Cox')
    
#     plt.subplot(133)
#     sns.kdeplot(X_train_transformed_yeo[col])
#     plt.title('Yeo-Johnson')

#     plt.show()

# %%
# Fitting the model on data transformed using Box-Cox:-

lr_box = LinearRegression()
lr_box.fit(X_train_transformed_box,y_train)

y_pred = lr_box.predict(X_test_transformed_box)

lnr_r2 = r2_score(y_test,y_pred)

lnr_r2
# Out:
# 0.6998280804799626

# %%
np.mean(cross_val_score(lr_box,X,y,scoring='r2', cv=10))
# Out:
# 0.105806033547411

# %% [markdown]
# # Regression Trees

# %%
#  Training regression tree models with data(on which only standardization is applied)


reg_tree = DecisionTreeRegressor(random_state=2529)
parameters = {'criterion' : ['squared_error'], 'min_samples_split' : [i for i in range(10,60,5)], 'min_impurity_decrease' : [0.01, 0.05, 0.1, 0.2, 0.25, 0.5, 0.7], 'splitter' : ['best','random'], 'max_depth': [i for i in range(10, 40, 5)]}

tree_grid = GridSearchCV(reg_tree, param_grid = parameters, scoring = ['r2'], refit='r2', cv = 10, verbose=4).fit(X_train_transformed, y_train)

print(tree_grid.best_estimator_)
# Out:
# Fitting 10 folds for each of 840 candidates, totalling 8400 fits
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.207) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.634) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.679) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.900) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.830) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.560) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.867) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.010) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.344) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.812) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.030) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.698) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.623) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.889) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.819) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.672) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.855) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.566) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.679) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.708) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.222) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.656) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.668) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.901) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.840) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.558) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.863) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.037) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.380) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.757) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.301) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.640) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.694) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.875) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.784) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.714) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.864) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.533) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.707) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.747) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.358) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.661) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.677) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.903) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.847) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.554) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.876) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.074) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.451) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.874) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.193) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.620) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.855) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.864) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.701) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.815) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.836) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.585) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.783) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.711) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.119) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.686) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.681) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.901) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.854) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.564) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.878) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.058) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.493) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.864) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.148) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.629) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.782) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.853) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.762) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.743) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.836) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.077) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.519) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.596) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.169) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.688) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.824) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.890) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.839) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.560) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.850) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.399) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.476) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.697) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.145) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.625) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.790) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.754) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.756) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.819) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.834) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.419) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.239) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.727) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.131) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.688) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.821) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.895) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.839) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.554) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.860) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.394) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.476) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.696) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.030) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.701) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.792) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.755) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.749) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.812) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.831) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.581) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.396) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.648) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.168) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.680) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.823) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.897) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.833) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.543) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.874) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.390) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.450) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.695) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.146) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.612) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.662) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.779) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.617) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.804) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.831) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.394) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.737) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.694) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.168) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.580) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.818) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.901) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.826) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.569) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.863) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.402) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.450) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.696) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.090) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.607) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.561) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.717) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.503) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.804) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.714) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.540) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.426) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.688) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.155) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.580) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.679) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.815) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.826) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.576) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.863) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.401) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.443) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.696) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=-0.085) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.592) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.558) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.721) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.503) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.804) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.714) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.540) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.426) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.609) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.421) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.573) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.679) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.813) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.744) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.576) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.790) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.257) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.422) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.510) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=-0.085) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.521) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.587) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.721) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.498) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.804) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.700) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.554) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.641) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.597) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.207) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.683) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.677) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.900) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.840) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.568) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.870) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.029) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.456) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.826) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.065) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.681) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.709) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.891) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.771) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.763) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.822) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.399) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.642) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.709) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.183) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.667) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.671) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.899) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.847) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.559) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.861) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.042) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.455) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.764) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.251) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.653) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.697) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.866) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.778) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.700) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.826) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.409) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.725) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.735) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.361) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.669) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.682) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.900) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.857) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.553) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.876) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.075) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.455) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.813) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.185) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.618) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.854) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.868) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.767) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.812) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.836) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.590) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.688) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.698) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.122) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.696) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.681) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.899) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.857) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.564) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.877) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.057) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.497) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.866) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.148) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.629) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.799) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.853) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.762) total time=   0.0s
# ...
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.644) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=-0.002) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.660) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.772) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.748) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.799) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.797) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.829) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.433) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.486) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.655) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.051) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.676) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.785) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.885) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.800) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.524) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.816) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.405) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.451) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.644) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.165) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.660) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.539) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.743) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.659) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.799) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.829) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.565) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.486) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.655) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.051) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.576) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.785) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.885) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.800) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.530) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.816) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.405) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.451) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.644) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.154) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.553) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.571) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.716) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.500) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.799) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.735) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.560) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.678) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.704) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.051) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.576) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.654) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.799) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.800) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.530) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.816) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.405) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.451) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.644) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=-0.084) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.558) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.571) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.716) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.485) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.799) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.735) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.511) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.678) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.612) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.317) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.576) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.654) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.799) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.745) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.530) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.743) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.266) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.430) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.466) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=-0.084) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.558) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.571) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.716) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.485) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.799) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.688) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.509) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.678) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.601) total time=   0.0s
# DecisionTreeRegressor(max_depth=15, min_impurity_decrease=0.05,
#                       min_samples_split=20, random_state=2529,
#                       splitter='random')

# %%
print(tree_grid.best_score_)
# Out:
# 0.6976376389342946

# %%
best_model = tree_grid.best_estimator_
y_pred = best_model.predict(X_test_transformed)
print(r2_score(y_test, y_pred))
reg_tree_r2 = r2_score(y_test, y_pred)
# Out:
# 0.7633660471203758

# %%
np.mean(cross_val_score(best_model,X,y,scoring='r2',cv=10))
# Out:
# 0.18835949419300566

# %% [markdown]
# # Regression Tree with Box-Cox transformed data

# %%
tree_transformed_grid = GridSearchCV(reg_tree, param_grid = parameters, scoring = ['r2'], refit='r2', cv=10, verbose=4).fit(X_train_transformed_box, y_train)
# Out:
# Fitting 10 folds for each of 840 candidates, totalling 8400 fits
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.207) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.631) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.679) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.906) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.830) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.560) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.862) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.010) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.344) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.812) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.168) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.651) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.816) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.717) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.856) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.607) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.812) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.819) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.693) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.501) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.222) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.656) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.668) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.907) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.840) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.558) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.858) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.037) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.380) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.757) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.181) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.649) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.831) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.692) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.801) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.502) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.850) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.820) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.752) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.809) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.358) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.661) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.677) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.910) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.847) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.554) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.871) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.074) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.451) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.874) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.383) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.652) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.744) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.730) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.850) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.494) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.860) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.783) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.780) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.826) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.119) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.686) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.681) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.901) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.854) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.564) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.873) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.058) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.493) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.864) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.506) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.665) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.808) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.749) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.855) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.509) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.838) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.810) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.712) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.706) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.169) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.688) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.824) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.890) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.839) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.560) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.845) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.399) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.476) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=best; r2: (test=0.697) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.500) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.717) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.750) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.715) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.852) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.401) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.875) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.852) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.693) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=30, random_state=2529, splitter=random; r2: (test=0.690) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.131) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.688) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.821) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.895) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.839) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.554) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.855) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.394) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.476) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.696) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.506) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.698) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.766) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.668) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.684) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.481) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.863) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.876) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.691) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.685) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.168) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.680) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.823) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.897) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.833) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.543) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.874) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.390) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.450) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.695) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.561) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.676) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.691) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.665) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.817) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.485) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.855) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.876) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.692) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.609) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.168) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.580) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.818) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.901) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.826) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.569) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.863) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.402) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.450) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.696) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.552) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.676) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.747) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.667) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.795) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.485) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.855) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.843) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.675) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.574) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.155) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.580) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.679) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.815) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.826) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.576) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.863) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.401) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.443) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.696) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.564) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.672) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.747) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.679) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.797) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.485) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.837) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.858) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.737) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.614) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.421) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.573) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.679) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.813) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.744) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.576) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.790) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.257) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.422) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.510) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.502) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.672) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.747) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.679) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.797) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.449) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.837) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.831) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.737) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.01, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.639) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.207) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.683) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.677) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.906) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.840) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.568) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.866) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.029) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.456) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=best; r2: (test=0.826) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.178) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.711) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.700) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.685) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.863) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.619) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.853) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.826) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.667) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=10, random_state=2529, splitter=random; r2: (test=0.577) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.183) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.667) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.671) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.906) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.847) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.559) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.856) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.042) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.455) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=best; r2: (test=0.764) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.194) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.758) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.707) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.696) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.807) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.697) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.755) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.835) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.711) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=15, random_state=2529, splitter=random; r2: (test=0.805) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.361) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.669) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.682) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.907) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.857) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.553) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.871) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.075) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.455) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=best; r2: (test=0.813) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.373) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.656) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.743) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.735) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.851) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.483) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.845) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.826) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.768) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=20, random_state=2529, splitter=random; r2: (test=0.826) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.122) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.696) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.681) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.899) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.857) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.564) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.872) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.057) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.497) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=best; r2: (test=0.866) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.506) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.666) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.808) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.743) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=10, min_impurity_decrease=0.05, min_samples_split=25, random_state=2529, splitter=random; r2: (test=0.855) total time=   0.0s
# ...
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.468) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=best; r2: (test=0.644) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.440) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.708) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.710) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.638) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.716) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.464) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.877) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.868) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.692) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=35, random_state=2529, splitter=random; r2: (test=0.606) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.051) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.676) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.785) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.885) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.800) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.524) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.816) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.405) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.451) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=best; r2: (test=0.644) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.444) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.670) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.710) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.638) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.771) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.464) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.811) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.868) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.672) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=40, random_state=2529, splitter=random; r2: (test=0.606) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.051) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.576) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.785) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.885) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.800) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.530) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.816) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.405) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.451) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=best; r2: (test=0.644) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.444) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.670) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.710) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.638) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.762) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.464) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.811) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.848) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.672) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=45, random_state=2529, splitter=random; r2: (test=0.606) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.051) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.576) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.654) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.799) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.800) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.530) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.816) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.405) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.451) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=best; r2: (test=0.644) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.444) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.670) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.710) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.638) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.762) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.464) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.811) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.848) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.670) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=50, random_state=2529, splitter=random; r2: (test=0.606) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.317) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.576) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.654) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.799) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.745) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.530) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.743) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.266) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.430) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=best; r2: (test=0.466) total time=   0.0s
# [CV 1/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.444) total time=   0.0s
# [CV 2/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.670) total time=   0.0s
# [CV 3/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.710) total time=   0.0s
# [CV 4/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.638) total time=   0.0s
# [CV 5/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.762) total time=   0.0s
# [CV 6/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.455) total time=   0.0s
# [CV 7/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.811) total time=   0.0s
# [CV 8/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.848) total time=   0.0s
# [CV 9/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.670) total time=   0.0s
# [CV 10/10] END criterion=squared_error, max_depth=35, min_impurity_decrease=0.7, min_samples_split=55, random_state=2529, splitter=random; r2: (test=0.623) total time=   0.0s

# %%
print(tree_transformed_grid.best_estimator_)
print(tree_transformed_grid.best_score_)
# Out:
# DecisionTreeRegressor(max_depth=10, min_impurity_decrease=0.1,
#                       min_samples_split=10, random_state=2529,
#                       splitter='random')
# 0.7704613822180942

# %%
best_model1 = tree_transformed_grid.best_estimator_
y_pred = best_model.predict(X_test_transformed_box)
print(r2_score(y_test, y_pred))
# Out:
# 0.6267970542725123

# %%
np.mean(cross_val_score(best_model,X,y,scoring='r2',cv=10))
# Out:
# 0.18835949419300566

# %%
print(f"The best accuracy for Linear Regression model is {lnr_r2}")
print(f"The best accuracy achieved using Regression Tree model is {reg_tree_r2}")
# Out:
# The best accuracy for Linear Regression model is 0.6998280804799626
# The best accuracy achieved using Regression Tree model is 0.7633660471203758

# %%
#After executing the code below, a file named 'tree.png' would be generated which contains the decision tree image
from sklearn.tree import export_graphviz
export_graphviz(best_model, out_file='tree.dot', filled=True, feature_names=list(X_train.columns))
# !dot -Tpng tree.dot -o tree.png
